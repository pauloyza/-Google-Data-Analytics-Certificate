# %% [markdown]
# #  E.G with dataframes (visualization)

# %% [markdown]
# ### 1) csv TO df

# %%
import pandas as pd 

# url = "Link from the internet, if we will use a ready study case"

# df = pd.read_csv(url)

# %% [markdown]
# #### 1.1) csv without header

# %%
# df = pd.read_csv(url, header = None)

# %% [markdown]
# ### 2) Print DF

# %%
# df # 
# df.head(n) #to show the first n rows
# df.tail(n) #to show the bottom n rows

# %% [markdown]
# ### 3) Adding Headers

# %%
# headers = [#array of headers (strings)]
#df.columns = headers

# %% [markdown]
# ### 4) DF to csv

# %%
# path = A path String e.g "C:\Windows\..."
# df.to_csv(path)

#IN GENERAL
#DATA FORMAT: example
#READ: pd.read_example()
#SAVE: df.to_example()

# %% [markdown]
# ### 5) Types

# %%
#df.dtypes

# %% [markdown]
# ### 6) Statistical Summary

# %%
#df.describe()
#argument include="all" # the statistical view of the DF is, with this command, a complete report

#The "string" things will not work so well. Classifications methods gonna be good to solve it.

# %% [markdown]
# ### 7) Concise summary

# %%
#df.info()
